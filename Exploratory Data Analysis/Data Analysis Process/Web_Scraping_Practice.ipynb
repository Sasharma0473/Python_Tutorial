# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
requests.get('https://timesofindia.indiatimes.com/city/delhi')
# Out:
# <Response [200]>

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}

# %%
webpage = requests.get('https://timesofindia.indiatimes.com/city/delhi').text

# %%
soup = BeautifulSoup(webpage,'lxml')

# %%
print(soup.title.string,type(soup.title.string))
# Out:
# Delhi News:दिल्ली समाचार -Latest Delhi News Headlines & Live Updates from Delhi, Delhi Local News Updates, Breaking Delhi News - Times of India <class 'bs4.element.NavigableString'>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
#  <head>
#   <link href="//static.toiimg.com" rel="preconnect"/>
#   <link href="//securepubads.g.doubleclick.net" rel="preconnect"/>
#   <link href="//pagead2.googlesyndication.com" rel="preconnect"/>
#   <link href="//ads.pubmatic.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="//assets.toiimg.com" rel="preconnect"/>
#   <link as="script" fetchpriority="high" href="https://assets.toiimg.com/js/til_prebid.js?v=15" rel="preload"/>
#   <link as="script" fetchpriority="high" href="https://c.amazon-adsystem.com/aax2/apstag.js" rel="preload"/>
#   <link as="script" fetchpriority="high" href="https://securepubads.g.doubleclick.net/tag/js/gpt.js?network-code=7176" rel="preload"/>
#   <link as="script" fetchpriority="high" href="https://timesofindia.indiatimes.com/toiads_prebid/minify-1.cms" rel="preload"/>
#   <link as="style" href="https://assets.toiimg.com/assets/11024.f155f208.chunk.css" rel="preload" type="text/css"/>
# ...

# %%
for i in soup.find_all('h2'):
    print(i.text.strip())
# Out:
# TOI
# More from delhi
# More Stories
# Photos
# Entertainment
# Lifestyle
# Television

# %%
for i in soup.find_all('h3'):
    print(i.text.strip())
# Out:
# Trending Topics
# AQI Updates

# %%
for i in soup.find_all('h4'):
    print(i.text.strip())
# Out:
# Other Times Group News Sites
# Popular Categories
# Hot on the Web
# Top Trends
# Trending Topics
# Living and entertainment
# Services
# Latest News

# %%
for i in soup.find_all('span'):
    print(i.text)
# Out:
# Edition
# IN
# Sign In
# Sign In
#
#
#
# News
# City News
# delhi News
# Delhi Air Pollution
# CM Atishi
# Delhi Car Fire
# Farmers Protest
# Trending Topics
#
# Farmers' protest: Noida-to-Delhi feels pain of ‘farm fire’
# 'Education my biggest ambition': Motivational speaker Avadh Ojha after joining AAP
# Drone survey of 550 sqkm area done, to curb encroachments in city
# Frauds strike 3 companies, escape with Rs 7cr
# HC seeks ED’s stand on Sisodia’s challenge to prosecution without sanction
#
# Cong targets govt over garbage issues
# Poster Boys Who Are No Role Models
# Delhi BJP may not name CM face for Delhi polls
# MCD Invites Bids For Landfill Ops
# MCD selects agency for plant near abattoir
# Man kills wife, keeps corpse in his truck for days; arrested
# Gang member held at metro station with pistols, ammo
# LG nod to new fines on wrong weights
# Delhi Police chief orders seven-day drive against gangsters
# 3% vehicles may be retrofitted by 2026
# ...

# %%
for i in soup.find_all('title'):
    print(i.text)
# Out:
# Delhi News:दिल्ली समाचार -Latest Delhi News Headlines & Live Updates from Delhi, Delhi Local News Updates, Breaking Delhi News - Times of India

# %%
for i in soup.find_all('a'):
    print(i.text)
# Out:
# IN
# US
# Read ePaper
#
# TOI
# City
# delhi
# mumbai
# bengaluru
# Hyderabad
# kolkata
# chennai
# agra
# agartala
# ahmedabad
# ajmer
# amaravati
# amritsar
# bareilly
# bhubaneswar
# bhopal
# chandigarh
# chhatrapati sambhajinagar
# coimbatore
# cuttack
# dehradun
# erode
# faridabad
# ghaziabad
# goa
# gurgaon
# guwahati
# hubballi
# imphal
# indore
# itanagar
# jaipur
# jammu
# jamshedpur
# jodhpur
# kanpur
# kochi
# kohima
# kolhapur
# kozhikode
# ludhiana
# lucknow
# madurai
# mangaluru
# meerut
# mumbai region
# mysuru
# nagpur
# nashik
# navi mumbai
# noida
# patna
# prayagraj
# puducherry
# pune
# raipur
# rajkot
# ranchi
# thane
# salem
# shillong
# shimla
# srinagar
# surat
# trichy
# thiruvananthapuram
# udaipur
# vadodara
# varanasi
# vijayawada
# visakhapatnam
# photos
# Web Stories
# photos
# weather
# News
# City News
# delhi News
# Delhi Air Pollution
# CM Atishi
# Delhi Car Fire
# Farmers Protest
# ...

# %%
for i in soup.find_all('a'):
    print(i.get('href'))
# Out:
# https://timesofindia.indiatimes.com/
# https://timesofindia.indiatimes.com/us
# https://epaper.indiatimes.com/timesepaper/publication-the-times-of-india,city-delhi.cms?redirectionSource=TOIWeb
# https://timesofindia.indiatimes.com/
# https://timesofindia.indiatimes.com
# https://timesofindia.indiatimes.com/city
# https://timesofindia.indiatimes.com/city/delhi
# https://timesofindia.indiatimes.com/city/mumbai
# https://timesofindia.indiatimes.com/city/bangalore
# https://timesofindia.indiatimes.com/city/hyderabad
# https://timesofindia.indiatimes.com/city/kolkata
# https://timesofindia.indiatimes.com/city/chennai
# https://timesofindia.indiatimes.com/city/agra
# https://timesofindia.indiatimes.com/city/agartala
# https://timesofindia.indiatimes.com/city/ahmedabad
# https://timesofindia.indiatimes.com/city/ajmer
# https://timesofindia.indiatimes.com/city/amaravati
# https://timesofindia.indiatimes.com/city/amritsar
# https://timesofindia.indiatimes.com/city/bareilly
# ...

# %%
for i in soup.find_all('a'):
    print(i.get_text())
# Out:
# IN
# US
# Read ePaper
#
# TOI
# City
# delhi
# mumbai
# bengaluru
# Hyderabad
# kolkata
# chennai
# agra
# agartala
# ahmedabad
# ajmer
# amaravati
# amritsar
# bareilly
# bhubaneswar
# bhopal
# chandigarh
# chhatrapati sambhajinagar
# coimbatore
# cuttack
# dehradun
# erode
# faridabad
# ghaziabad
# goa
# gurgaon
# guwahati
# hubballi
# imphal
# indore
# itanagar
# jaipur
# jammu
# jamshedpur
# jodhpur
# kanpur
# kochi
# kohima
# kolhapur
# kozhikode
# ludhiana
# lucknow
# madurai
# mangaluru
# meerut
# mumbai region
# mysuru
# nagpur
# nashik
# navi mumbai
# noida
# patna
# prayagraj
# puducherry
# pune
# raipur
# rajkot
# ranchi
# thane
# salem
# shillong
# shimla
# srinagar
# surat
# trichy
# thiruvananthapuram
# udaipur
# vadodara
# varanasi
# vijayawada
# visakhapatnam
# photos
# Web Stories
# photos
# weather
# News
# City News
# delhi News
# Delhi Air Pollution
# CM Atishi
# Delhi Car Fire
# Farmers Protest
# ...

# %%
for i in soup.find_all('div'):
    print(i.text)
# Out:
# EditionININUSRead ePaperSign InTOICitydelhimumbaibengaluruHyderabadkolkatachennaiagraagartalaahmedabadajmeramaravatiamritsarbareillybhubaneswarbhopalchandigarhchhatrapati sambhajinagarcoimbatorecuttackdehradunerodefaridabadghaziabadgoagurgaonguwahatihubballiimphalindoreitanagarjaipurjammujamshedpurjodhpurkanpurkochikohimakolhapurkozhikodeludhianalucknowmaduraimangalurumeerutmumbai regionmysurunagpurnashiknavi mumbainoidapatnaprayagrajpuducherrypuneraipurrajkotranchithanesalemshillongshimlasrinagarsurattrichythiruvananthapuramudaipurvadodaravaranasivijayawadavisakhapatnamphotosWeb StoriesphotosweatherNewsCity Newsdelhi NewsTrendingDelhi Air PollutionCM AtishiDelhi Car FireFarmers Protestdelhi NewsWatch: Delhi bizman sets car on fire after tiff in Lajpat NagarA businessman was arrested in southeast Delhi for setting a poet's car on fire after a parking dispute. CCTV footage shows the suspects vandalizing and igniting Kunwar Ranjeet Chauhan's car. After a 600-km chase, Rahul Bhasin and 
# ...

# %%
for i in soup.find_all('p'):
    print(i.text)
# Out:
# A businessman was arrested in southeast Delhi for setting a poet's car on fire after a parking dispute. CCTV footage shows the suspects vandalizing and igniting Kunwar Ranjeet Chauhan's car. After a 600-km chase, Rahul Bhasin and six others were apprehended. The incident stemmed from ongoing harassment despite previous police intervention.
# Over the past week, east Delhi has witnessed a surge in snatching and robbery incidents, with six cases reported. The incidents involved serious violence, including a stabbing, an attack with a brick, and threats with blades. Police have filed FIRs and are investigating using CCTV footage, with one minor apprehended.
# ...

# %%
soup.find_all('div', class_='container')[0].text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 soup.find_all('div', class_='container')[0].text
#
# IndexError: list index out of range

# %%
print(soup.find_all("p"))
# Out:
# [<p class="">A businessman was arrested in southeast Delhi for setting a poet's car on fire after a parking dispute. CCTV footage shows the suspects vandalizing and igniting Kunwar Ranjeet Chauhan's car. After a 600-km chase, Rahul Bhasin and six others were apprehended. The incident stemmed from ongoing harassment despite previous police intervention.</p>, <p class="">Over the past week, east Delhi has witnessed a surge in snatching and robbery incidents, with six cases reported. The incidents involved serious violence, including a stabbing, an attack with a brick, and threats with blades. Police have filed FIRs and are investigating using CCTV footage, with one minor apprehended.</p>, <p class="YNjii">Commuters face persistent issues on the neglected street near Delhi’s old Police Headquarters and Public Works Department buildings. Hazardous open drains and stalled construction work have led to damages for numerous vehicles and pose significant risks to vendors and pedestrians. Des
# ...

# %%
print(soup.get_text())
# Out:
# Delhi News:दिल्ली समाचार -Latest Delhi News Headlines & Live Updates from Delhi, Delhi Local News Updates, Breaking Delhi News - Times of IndiaEditionININUSRead ePaperSign InTOICitydelhimumbaibengaluruHyderabadkolkatachennaiagraagartalaahmedabadajmeramaravatiamritsarbareillybhubaneswarbhopalchandigarhchhatrapati sambhajinagarcoimbatorecuttackdehradunerodefaridabadghaziabadgoagurgaonguwahatihubballiimphalindoreitanagarjaipurjammujamshedpurjodhpurkanpurkochikohimakolhapurkozhikodeludhianalucknowmaduraimangalurumeerutmumbai regionmysurunagpurnashiknavi mumbainoidapatnaprayagrajpuducherrypuneraipurrajkotranchithanesalemshillongshimlasrinagarsurattrichythiruvananthapuramudaipurvadodaravaranasivijayawadavisakhapatnamphotosWeb StoriesphotosweatherNewsCity Newsdelhi NewsTrendingDelhi Air PollutionCM AtishiDelhi Car FireFarmers Protestdelhi NewsWatch: Delhi bizman sets car on fire after tiff in Lajpat NagarA businessman was arrested in southeast Delhi for setting a poet's car on fire after a 
# ...

# %%
for child in soup.find_all('li',class_='sBgUN col'):
    print(child)
# Out:
# <li class="sBgUN col"><a aria-label="mumbai" class="rxTTw null undefined" commonstate="[object Object]" data-ga="nav_menu|L1_parent|mumbai" frmappuse="1" href="https://timesofindia.indiatimes.com/city/mumbai" rel="noopener">mumbai</a><meta content="mumbai" itemprop="name"/><meta content="https://timesofindia.indiatimes.com/city/mumbai" itemprop="url"/></li>
# <li class="sBgUN col"><a aria-label="bengaluru" class="rxTTw null undefined" commonstate="[object Object]" data-ga="nav_menu|L1_parent|bengaluru" frmappuse="1" href="https://timesofindia.indiatimes.com/city/bangalore" rel="noopener">bengaluru</a><meta content="bengaluru" itemprop="name"/><meta content="https://timesofindia.indiatimes.com/city/bangalore" itemprop="url"/></li>
# ...

# %%
for child in soup.find_all(class_ = 'container').children:
    print(child)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 for child in soup.find_all(class_ = 'container').children:
#       2     print(child)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\bs4\element.py:2428, in ResultSet.__getattr__(self, key)
#    2426 def __getattr__(self, key):
#    2427     """Raise a helpful exception to explain a common code fix."""
# -> 2428     raise AttributeError(
#    2429         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2430     )
#
# AttributeError: ResultSet object has no attribute 'children'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
print(soup.find_all(class_="container"))
# Out:
# []
